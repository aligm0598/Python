# %%
import pandas as pd

# %%
delays_df = pd.read_csv('Data/flight_delays.csv')
delays_df.head()
# Out:
# /var/folders/q8/qd6l4h9s7gn2bk4rq1l2v7vw0000gq/T/ipykernel_97968/1244664022.py:1: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   delays_df = pd.read_csv('Data/flight_delays.csv')
#    YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 0  2015      1    1            4      AS             98      N407AS
# 1  2015      1    1            4      AA           2336      N3KUAA
# 2  2015      1    1            4      US            840      N171US
# 3  2015      1    1            4      AA            258      N3HYAA
# 4  2015      1    1            4      AS            135      N527AS
#
#   ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  ...  ARRIVAL_TIME  \
# 0            ANC                 SEA                    5  ...         408.0
# 1            LAX                 PBI                   10  ...         741.0
# 2            SFO                 CLT                   20  ...         811.0
# ...

# %%
new_df = delays_df.drop(columns=['FLIGHT_NUMBER'])
new_df.head()
# Out:
#    YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE TAIL_NUMBER ORIGIN_AIRPORT  \
# 0  2015      1    1            4      AS      N407AS            ANC
# 1  2015      1    1            4      AA      N3KUAA            LAX
# 2  2015      1    1            4      US      N171US            SFO
# 3  2015      1    1            4      AA      N3HYAA            LAX
# 4  2015      1    1            4      AS      N527AS            SEA
#
#   DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  DEPARTURE_TIME  ...  ARRIVAL_TIME  \
# 0                 SEA                    5          2354.0  ...         408.0
# 1                 PBI                   10             2.0  ...         741.0
# 2                 CLT                   20            18.0  ...         811.0
# 3                 MIA                   20            15.0  ...         756.0
# 4                 ANC                   25            24.0  ...         259.0
#
#    ARRIVAL_DELAY  DIVERTED  CANCELLED  CANCELLATION_REASON  AIR_SYSTEM_DELAY  \
# ...

# %%
delays_df.drop(columns=['TAIL_NUMBER'], inplace=True)
delays_df.head()
# Out:
#    YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER ORIGIN_AIRPORT  \
# 0  2015      1    1            4      AS             98            ANC
# 1  2015      1    1            4      AA           2336            LAX
# 2  2015      1    1            4      US            840            SFO
# 3  2015      1    1            4      AA            258            LAX
# 4  2015      1    1            4      AS            135            SEA
#
#   DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  DEPARTURE_TIME  ...  ARRIVAL_TIME  \
# 0                 SEA                    5          2354.0  ...         408.0
# 1                 PBI                   10             2.0  ...         741.0
# 2                 CLT                   20            18.0  ...         811.0
# 3                 MIA                   20            15.0  ...         756.0
# 4                 ANC                   25            24.0  ...         259.0
#
# ...

# %%
desc_df = delays_df.loc[:,['AIRLINE','ORIGIN_AIRPORT','DESTINATION_AIRPORT']]
desc_df.head()
# Out:
#   AIRLINE ORIGIN_AIRPORT DESTINATION_AIRPORT
# 0      AS            ANC                 SEA
# 1      AA            LAX                 PBI
# 2      US            SFO                 CLT
# 3      AA            LAX                 MIA
# 4      AS            SEA                 ANC
